# %%
#kita pake package gdal untuk olah data rasternya
from osgeo import gdal

# %%
#data 1 ini kita buka file data raster yang kita punya untuk diolah. Copas aja lokasinya di mana atau kalo kamu nyimpan di directory jupyternya bisa langsung tulis nama filenya
data1 = gdal.Open("D:\download\Tutorial Data\Tutorial Data\Bompon\dem.tif", gdal.GA_ReadOnly)
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\osgeo\gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(

# %%
#ini kita mau transform datanya ke data geo gitu lah. GT for GeoTransform
GT_input = data1.GetGeoTransform()

# %%
#data 2 ini tuh kita mo pake band 1 di data 1. kan band data rasternya 1 yak. beda kalo data raster citra rgb
data2 = data1.GetRasterBand(1)

# %%
#ini kita ubah data 2 itu jadi array. fungsinya biar bisa dikalikan ngono nilainya
img_as_array = data2.ReadAsArray()

# %%
#ini pembacaan size data array-nya
data1,data2=img_as_array.shape

# %%
#ini pake package numpy karena mo ngali2in data array-nya
import numpy as np
#ini buat output dengan ukuran dimensi sama dg data 1 dan 2
output=np.zeros(shape=(data1,data2))

# %%
#ini function untuk mengalikan nilai di output td dengan variable yang kita inginkan
for i in range(0,size1):
    for j in range(0,size2):
        output[i,j]=img_as_array[i,j] *0.5*100*9.8

# %%
#rasterio ni package untuk olah data raster pokoke wkwk
import rasterio

# %%
#ini set crs nya
dst_crs='EPSG:4326'

# %%
#ini kita ubah data hasil kali td ke data float soalnya mo di-export ke data raster lagi
output = np.float32(output)

# %%
#nah ini lah function untuk export data output td ke data raster pake rasterio
with rasterio.open(
    'output_map.tif',
    'w',
    driver='GTiff',
    height=output.shape[0],
    width=output.shape[1],
    count=1,
    dtype=np.float32,
    crs=dst_crs,
    geotransform=GT_input,
) as dest_file:
    dest_file.write(output, 1)
dest_file.close()
