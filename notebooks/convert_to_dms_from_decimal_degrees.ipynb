# %%
import pandas as pd

# Function to convert decimal degrees to DMS
def decimal_to_dms(deg):
    d = int(deg)
    m = int((deg - d) * 60)
    s = (deg - d - m/60) * 3600
    return f"{d}°{m}'{s:.2f}\""

# Load the CSV file into a DataFrame
df = pd.read_csv("C:/Users/ACER/Downloads/sungaiundan_new.csv")

# Apply the conversion function to each row
df['latitude_dms'] = df['latitude'].apply(decimal_to_dms)
df['longitude_dms'] = df['longitude'].apply(decimal_to_dms)

# Save the updated DataFrame to a new CSV file
df.to_csv('updated_dataset_sungaiundan.csv', index=False)

print("Conversion to DMS completed and saved to 'updated_dataset_sungaiundan.csv'")
# Out:
# Conversion to DMS completed and saved to 'updated_dataset_sungaiundan.csv'

# %%
df
# Out:
#                                                                               FID;Shape *;luas_ha;kode_poli;kelompok;pola_tanam;ket_lokasi;kel_bio;tipologi;desa;kecamatan;kab_kota;provinsi;penerimaan;inf_terima;hidrologi;cttn_hidro;fungsi_kws;LUAS_RK;kategori;Tup_Lah;longitude;latitude
# 0;Polygon ZM;1  718813;R1_Seberang Pulau Kijang_72;POKMAS Teras... 411599;-0                                             669128
# 1;Polygon ZM;2  042315;R1_Seberang Pulau Kijang_72;POKMAS Teras... 410713;-0                                             669499
# 2;Polygon ZM;2  131178;R1_Seberang Pulau Kijang_72;POKMAS Teras... 40976;-0                                              669778
# 3;Polygon ZM;4  250217;R1_Seberang Pulau Kijang_72;POKMAS Teras... 41002;-0                                              667736
# 4;Polygon ZM;2  18105;R1_Seberang Pulau Kijang_72;POKMAS Teras ... 408703;-0                                             668265
# ...
